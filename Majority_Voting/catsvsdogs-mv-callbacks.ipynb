# %%
import tensorflow_datasets as tfds
import tensorflow as tf

import keras
from keras.models import Sequential,Model
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,GlobalAveragePooling2D
from keras.utils.vis_utils import plot_model
from tensorflow.keras import regularizers
from keras.layers import Activation, Dropout, Flatten, Dense, Input
from keras.layers import BatchNormalization
from sklearn.metrics import roc_auc_score



import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import cv2
import os
import time
import sys

# os.chdir('/content/drive/Shareddrives/Multiple Anotators/CrowdLayer/Notebooks')
# cwd = os.getcwd()
# sys.path.append("../Models")


# from Multiple_Annotators_C import MultipleAnnotators_Classification

import sys
sys.path.insert(1, '../input/multiple-annotators-c/')
#os.chdir('/Multiple Anotators-c/')
#cwd = os.getcwd()
sys.path.append('/input/multiple-annotators-c')
from Multiple_Annotators_C import MultipleAnnotators_Classification

# seed_value= 12321 
# from numpy.random import seed
# seed(seed_value)
# tf.random.set_seed(seed_value)

# %%
import tensorflow as tf
import numpy as np
from scipy.io import loadmat
from sklearn.preprocessing import StandardScaler
from scipy.io import savemat
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from scipy.stats import mode 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.metrics import roc_auc_score
from sklearn.decomposition import PCA

def ook(t):
  lb = LabelBinarizer()
  y_ook = lb.fit_transform(t)  

  if len(np.unique(t))==2:
    y_ook = np.concatenate((1-y_ook.astype(bool), y_ook), axis = 1) 

  return y_ook


def scheduler1(step = 10, ratio = 1.2):
  def scheduler(epoch, lr):
    if epoch % step == 0 and epoch>1:
      return lr/ratio
    else:
      return lr
  return scheduler

# %%
train_data = tf.data.experimental.load('/kaggle/input/cat-dogs-mv/cats_dogs_MV_Tr_1')
Test_data = tf.data.experimental.load('../input/catsvsdog-ma/cats_dogs_Te')
# Out:
# 2023-02-14 11:50:05.618819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:05.769724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:05.770639: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:05.771998: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-14 11:50:05.780649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:05.781378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:05.782123: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:07.872387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:07.873238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:07.873941: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-14 11:50:07.875215: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
image_count_train = tf.data.experimental.cardinality(train_data).numpy()
image_count_train
# Out:
# 18610

# %%
image_count_test = tf.data.experimental.cardinality(Test_data).numpy()
image_count_test
# Out:
# 4652

# %%
subset = 18610
train_data = train_data.take(18610)
image_count1 = tf.data.experimental.cardinality(train_data).numpy()
image_count1
# Out:
# 18610

# %%
image_count = 3000
 
val_size = int(image_count1 * 0.25)
train_ds = train_data.skip(val_size)
val_ds  = train_data.take(val_size)

# %%
image_count_val = tf.data.experimental.cardinality(val_ds).numpy()
image_count_val
# Out:
# 4652

# %%
image_count_Tr = tf.data.experimental.cardinality(train_ds).numpy()
image_count_Tr
# Out:
# 13958

# %%
classNames = ['cat', 'dog']


i = 0

fig, ax = plt.subplots(1, 7, figsize=(15,15))
 
for image,label, label2 in train_ds.take(7):
 #  print(image.shape)
 #   predictedLabel = int(predictions[i] >= 0.5)
   # print(label)
   ax[i].axis('off')
  # ax[i].set_title(classNames[label.numpy()])
   ax[i].imshow(image)
    
   i += 1
 
# plt.show()
# Out:
# 2023-02-14 11:50:08.881552: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
# shuffle and create batches before training
batch_size = 128
train_batches = train_ds.shuffle(1024).batch(batch_size)
val_batches  = val_ds.shuffle(1024).batch(batch_size)
test_batches =  Test_data.shuffle(1024).batch(batch_size)

# %%
image_count_test = tf.data.experimental.cardinality(test_batches).numpy()
image_count_test
# Out:
# 37

# %% [markdown]
# **Build the GOLD STANDARD classifier**
#
#
# This will look familiar to you because it is almost identical to the previous model we built. The key difference is the output is just one unit that is sigmoid activated. This is because we're only dealing with two classes.

# %%
def build_base_model():
    # base_model = Sequential()


    # base_model.add( Conv2D(32, (3, 3), activation='relu',
    # input_shape=(150, 150, 3)))
    # base_model.add( MaxPooling2D((2, 2)))
    # base_model.add( Dropout(0.2))

    # base_model.add( Conv2D(64, (3, 3), activation='relu'))
    # base_model.add( MaxPooling2D((2, 2)))
    # base_model.add( Dropout(0.2))

    # base_model.add( Conv2D(128, (3, 3), activation='relu'))
    # base_model.add( MaxPooling2D((2, 2)))
    # base_model.add(Dropout(0.2))

    # base_model.add(Conv2D(256, (3, 3), activation='relu'))
    # base_model.add(MaxPooling2D((2, 2)))
    # base_model.add(Dropout(0.2))

    # base_model.add(Flatten())


    # base_model.add(Dense(256, activation='relu'))
    # base_model.add(Dense(1, activation='sigmoid'))

    initializer = tf.keras.initializers.GlorotNormal(seed=100)
    base_model = Sequential()
    base_model.add(BatchNormalization())
    base_model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3),bias_initializer='zeros', kernel_initializer=initializer))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))
   
    base_model.add(BatchNormalization())
    base_model.add(Conv2D(32, (3, 3),bias_initializer='zeros', kernel_initializer=initializer))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))
    

    base_model.add(BatchNormalization())
    base_model.add(Conv2D(64, (3, 3), bias_initializer='zeros', kernel_initializer=initializer))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))

    base_model.add(BatchNormalization())
    base_model.add(Conv2D(64, (3, 3), bias_initializer='zeros', kernel_initializer=initializer))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))


    base_model.add(Flatten()) 
    base_model.add(BatchNormalization())
    base_model.add(Dense(128, bias_initializer='zeros', kernel_initializer=initializer))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(Dropout(0.2))
    base_model.add(Dense(N_CLASSES, bias_initializer='zeros', kernel_initializer=initializer))
    base_model.add(Activation('softmax'))

    base_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3, clipnorm = 1.0), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return base_model

# %%
N_CLASSES = 2
def one_hot(image, ytrue, label):
    one_hot_targets = label  # tf.one_hot(tf.cast(label, tf.int32), N_CLASSES, axis = 1, dtype=tf.int32)
    return image, one_hot_targets

# %%
train_batches_MV = train_batches.map(one_hot)

# %%
val_batches_MV = val_batches.map(one_hot)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model1.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
callback1 = tf.keras.callbacks.TerminateOnNaN()
callback2 = tf.keras.callbacks.LearningRateScheduler(scheduler1(ratio = 1))
#callback2 = tf.keras.callbacks.LearningRateScheduler(scheduler2)
callback3 = tf.keras.callbacks.EarlyStopping(monitor="loss", min_delta=1e-2,
                                         patience=15, verbose=0, mode="auto",
                                         baseline=None, restore_best_weights=True)

# %%
K=2
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import normalized_mutual_info_score, mutual_info_score, adjusted_mutual_info_score
#l1 =0.0001
NUM_RUNS = 10
N_EPOCHS = 100
ACC = np.zeros(NUM_RUNS)
AUC = np.zeros(NUM_RUNS)
AUCSK = np.zeros(NUM_RUNS)
MI = np.zeros(NUM_RUNS)
NMI = np.zeros(NUM_RUNS)
AMI = np.zeros(NUM_RUNS)
BACC = np.zeros(NUM_RUNS)
BACC1 = []
MI1 = []
NMI1 =[]
AMI1 = []
AUCSK1 = []
val_acc_goldst = np.zeros(NUM_RUNS)
AUC= np.zeros(NUM_RUNS)
for i in range(NUM_RUNS):
    model = build_base_model()  
    trainHistory = model.fit(train_batches_MV, validation_data= val_batches_MV, epochs=N_EPOCHS,   callbacks = [callback1, callback2])
    (loss, accuracy) = model.evaluate(test_batches)
    #Accurarcy =================
    ACC[i] = accuracy
    print("Validation acc: %.4f" % (float(ACC[i]),))
 
    #AUC =======================
    val_AUC_metric = tf.keras.metrics.AUC( from_logits = True)
    for x_batch_val, y_batch_val in test_batches:
        val_logits = model(x_batch_val.numpy(), training=False)
       # tf.print(y_batch_val)
        val_AUC_metric.update_state(y_batch_val, val_logits.numpy().argmax(axis=1).astype('float'))   #val_logits[:,Y.shape[1]:].argmax(axis=1).astype('float'))
        val_AUC_metric.update_state(y_batch_val, val_logits[:,:K].numpy().argmax(axis=1).astype('float'))
        BACC1.append(balanced_accuracy_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze(), adjusted=True))
        MI1.append(mutual_info_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze()))
        NMI1.append(normalized_mutual_info_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze()))
        AMI1.append(normalized_mutual_info_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze()))
        AUCSK1.append(roc_auc_score(ook(y_batch_val.numpy()), val_logits[:,:K].numpy().astype('float')))

    val_AUC = val_AUC_metric.result()
    val_AUC_metric.reset_states()
    val_AUC = val_AUC.numpy()
    print("Validation AUC: %.4f" % (float(val_AUC),))
    AUC[i] = val_AUC
    #===================================================
    # balanced. Accurcy
    BACC[i] = np.array(BACC1).mean() # balanced_accuracy_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze(), adjusted=True)
    print("Validation Balanced_ACC: %.4f" % (float(BACC[i])))
    AUCSK[i] = np.array(AUCSK1).mean() 
    print("Validation AUCSK: %.4f" % (float( AUCSK[i] )))

    #MI

    MI[i] =  np.array(MI1).mean()  #mutual_info_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze())
    print("Validation MI: %.4f" % (float(MI[i]),))
    NMI[i] =  np.array(NMI1).mean()   #normalized_mutual_info_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze())
    print("Validation Normalized MI: %.4f" % (float(NMI[i]),))
    AMI[i]= np.array(AMI1).mean()  #adjusted_mutual_info_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze())
    print("Validation Adjusted MI: %.4f" % (float(AMI[i]),))

    
    
    # Create the history figure
    plt.figure(figsize=(16,9))
    for i in trainHistory.history:
        plt.plot(trainHistory.history[i],label=i)
    plt.title('Model history')
    plt.legend()
    plt.grid()
import pandas as pd

df_gold = pd.DataFrame(val_acc_goldst)
df_gold.to_csv('/kaggle/working/CatDogs_MA_VGG19_GOLD.csv',index=False) # save to notebook output
  

# plt.plot(trainHistory.history['accuracy'])
# plt.plot(trainHistory.history['val_accuracy'])
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Training', 'Validation'])
# plt.grid()
# plt.show()
# Out:
# Epoch 1/100
# 2023-02-14 11:50:36.635488: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 110/110 [==============================] - 90s 668ms/step - loss: 0.8729 - accuracy: 0.5219 - val_loss: 0.7042 - val_accuracy: 0.5107
# Epoch 2/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.7283 - accuracy: 0.5409 - val_loss: 0.7052 - val_accuracy: 0.5082
# Epoch 3/100
# 110/110 [==============================] - 11s 93ms/step - loss: 0.7036 - accuracy: 0.5589 - val_loss: 0.7080 - val_accuracy: 0.4970
# Epoch 4/100
# 110/110 [==============================] - 11s 93ms/step - loss: 0.6787 - accuracy: 0.5850 - val_loss: 0.6949 - val_accuracy: 0.5297
# Epoch 5/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.6596 - accuracy: 0.6016 - val_loss: 0.7059 - val_accuracy: 0.5247
# Epoch 6/100
# 110/110 [==============================] - 11s 94ms/step - loss: 0.6392 - accuracy: 0.6302 - val_loss: 0.7043 - val_accuracy: 0.5402
# Epoch 7/100
# 110/110 [==============================] - 11s 87ms/step - loss: 0.6150 - accuracy: 0.6563 - val_loss: 0.7237 - val_accuracy: 0.5477
# Epoch 8/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.5807 - accuracy: 0.6858 - val_loss: 0.7506 - val_accuracy: 0.5396
# Epoch 9/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0
100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 3.0750 - val_accuracy: 0.5447
# Epoch 88/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 3.0464 - val_accuracy: 0.5359
# Epoch 89/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 3.0066 - val_accuracy: 0.5355
# Epoch 90/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 3.1129 - val_accuracy: 0.5372
# Epoch 91/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0155 - accuracy: 0.9951 - val_loss: 3.0573 - val_accuracy: 0.5417
# Epoch 92/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 3.0885 - val_accuracy: 0.5415
# Epoch 93/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 3.1084 - val_accuracy: 0.5475
# Epoch 94/100
# 110/110 [==============================] - 11s 94ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 2.9393 - val_accuracy: 0.5449
# Epoch 95/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.0137 - accuracy: 0.9953 - val_loss: 3.0142 - val_accuracy: 0.5342
# Epoch 96/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 2.9885 - val_accuracy: 0.5443
# Epoch 97/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 3.0438 - val_accuracy: 0.5361
# Epoch 98/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 3.0188 - val_accuracy: 0.5333
# Epoch 99/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0166 - accuracy: 0.9944 - val_loss: 3.2003 - val_accuracy: 0.5441
# Epoch 100/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0147 - accuracy: 0.9942 - val_loss: 3.0763 - val_accuracy: 0.5451
# 37/37 [==============================] - 3s 64ms/step - loss: 2.4906 - accuracy: 0.5991
# Validation acc: 0.5991
# Validation AUC: 0.5990
# Validation Balanced_ACC: 0.2048
# Validation AUCSK: 0.6403
# Validation MI: 0.0244
# Validation Normalized MI: 0.0354
# Validation Adjusted MI: 0.0354
# Epoch 1/100
# 110/110 [==============================] - 13s 98ms/step - loss: 0.8604 - accuracy: 0.5171 - val_loss: 0.6951 - val_accuracy: 0.4948
# Epoch 2/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.7327 - accuracy: 0.5373 - val_loss: 0.6988 - val_accuracy: 0.4918
# Epoch 3/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.7055 - accuracy: 0.5618 - val_loss: 0.6974 - val_accuracy: 0.5028
# Epoch 4/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.6847 - accuracy: 0.5772 - val_loss: 0.6924 - val_accuracy: 0.5286
# Epoch 5/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6704 - accuracy: 0.5975 - val_loss: 0.6984 - val_accuracy: 0.5312
# Epoch 6/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.6531 - accuracy: 0.6184 - val_loss: 0.6923 - val_accuracy: 0.5501
# Epoch 7/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.6307 - accuracy: 0.6406 - val_loss: 0.7025 - val_accuracy: 0.5555
# Epoch 8/100
# 110/110 [==============================] - 11s 85ms/step - loss: 0.5915 - accuracy: 0.6823 - val_loss: 0.7329 - val_accuracy: 0.5525
# Epoch 9/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0
100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 2.8358 - val_accuracy: 0.5389
# Epoch 60/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0222 - accuracy: 0.9923 - val_loss: 2.8629 - val_accuracy: 0.5393
# Epoch 61/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0218 - accuracy: 0.9925 - val_loss: 2.8052 - val_accuracy: 0.5363
# Epoch 62/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.0167 - accuracy: 0.9938 - val_loss: 2.8741 - val_accuracy: 0.5430
# Epoch 63/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 2.8352 - val_accuracy: 0.5383
# Epoch 64/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 2.8398 - val_accuracy: 0.5419
# Epoch 65/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0211 - accuracy: 0.9923 - val_loss: 2.8829 - val_accuracy: 0.5374
# Epoch 66/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0219 - accuracy: 0.9917 - val_loss: 2.8957 - val_accuracy: 0.5389
# Epoch 67/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0214 - accuracy: 0.9933 - val_loss: 2.8942 - val_accuracy: 0.5337
# Epoch 68/100
# 110/110 [==============================] - 12s 99ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 2.8946 - val_accuracy: 0.5398
# Epoch 69/100
# 110/110 [==============================] - 13s 108ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 2.8450 - val_accuracy: 0.5423
# Epoch 70/100
# 110/110 [==============================] - 11s 94ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 2.7606 - val_accuracy: 0.5378
# Epoch 71/100
# 110/110 [==============================] - 11s 87ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 2.9681 - val_accuracy: 0.5374
# Epoch 72/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 3.0786 - val_accuracy: 0.5432
# Epoch 73/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0214 - accuracy: 0.9913 - val_loss: 3.0762 - val_accuracy: 0.5404
# Epoch 74/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.0206 - accuracy: 0.9931 - val_loss: 3.0612 - val_accuracy: 0.5456
# Epoch 75/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 2.7372 - val_accuracy: 0.5411
# Epoch 76/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0220 - accuracy: 0.9918 - val_loss: 3.0258 - val_accuracy: 0.5391
# Epoch 77/100
# 110/110 [==============================] - 10s 78ms/step - loss: 0.0219 - accuracy: 0.9920 - val_loss: 3.1105 - val_accuracy: 0.5426
# Epoch 78/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0213 - accuracy: 0.9932 - val_loss: 3.0928 - val_accuracy: 0.5488
# Epoch 79/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0200 - accuracy: 0.9927 - val_loss: 2.9897 - val_accuracy: 0.5426
# Epoch 80/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 2.9606 - val_accuracy: 0.5361
# Epoch 81/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 3.0102 - val_accuracy: 0.5353
# Epoch 82/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 2.9844 - val_accuracy: 0.5402
# Epoch 83/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0141 - accuracy: 0.9948 - val_loss: 2.9933 - val_accuracy: 0.5322
# Epoch 84/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 3.1353 - val_accuracy: 0.5333
# Epoch 85/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 3.0940 - val_accuracy: 0.5490
# Epoch 86/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 2.9155 - val_accuracy: 0.5421
# Epoch 87/100
# 110/110 [==============================] - 12s 98ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 3.0355 - val_accuracy: 0.5454
# Epoch 88/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 3.1405 - val_accuracy: 0.5370
# Epoch 89/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 3.0728 - val_accuracy: 0.5337
# Epoch 90/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0142 - accuracy: 0.9946 - val_loss: 3.1054 - val_accuracy: 0.5333
# Epoch 91/100
# 110/110 [==============================] - 11s 86ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 3.1119 - val_accuracy: 0.5353
# Epoch 92/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 3.1983 - val_accuracy: 0.5402
# Epoch 93/100
# 110/110 [==============================] - 11s 93ms/step - loss: 0.0170 - accuracy: 0.9938 - val_loss: 3.0352 - val_accuracy: 0.5344
# Epoch 94/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0228 - accuracy: 0.9918 - val_loss: 3.1158 - val_accuracy: 0.5406
# Epoch 95/100
# 110/110 [==============================] - 12s 96ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 3.1656 - val_accuracy: 0.5421
# Epoch 96/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 3.0800 - val_accuracy: 0.5445
# Epoch 97/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0182 - accuracy: 0.9934 - val_loss: 3.3222 - val_accuracy: 0.5385
# Epoch 98/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0158 - accuracy: 0.9943 - val_loss: 3.1210 - val_accuracy: 0.5439
# Epoch 99/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 3.0787 - val_accuracy: 0.5406
# Epoch 100/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 2.8962 - val_accuracy: 0.5464
# 37/37 [==============================] - 2s 44ms/step - loss: 2.3354 - accuracy: 0.6040
# Validation acc: 0.6040
# Validation AUC: 0.6044
# Validation Balanced_ACC: 0.2056
# Validation AUCSK: 0.6400
# Validation MI: 0.0253
# Validation Normalized MI: 0.0367
# Validation Adjusted MI: 0.0367
# Epoch 1/100
# 110/110 [==============================] - 12s 81ms/step - loss: 0.8689 - accuracy: 0.5259 - val_loss: 0.7131 - val_accuracy: 0.4888
# Epoch 2/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.7268 - accuracy: 0.5476 - val_loss: 0.7213 - val_accuracy: 0.5011
# Epoch 3/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.6896 - accuracy: 0.5754 - val_loss: 0.7022 - val_accuracy: 0.5082
# Epoch 4/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.6749 - accuracy: 0.5938 - val_loss: 0.7134 - val_accuracy: 0.5260
# Epoch 5/100
# 110/110 [==============================] - 11s 96ms/step - loss: 0.6530 - accuracy: 0.6189 - val_loss: 0.6952 - val_accuracy: 0.5462
# Epoch 6/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.6281 - accuracy: 0.6458 - val_loss: 0.7399 - val_accuracy: 0.5284
# Epoch 7/100
# 110/110 [==============================] - 12s 96ms/step - loss: 0.5991 - accuracy: 0.6745 - val_loss: 0.7353 - val_accuracy: 0.5469
# Epoch 8/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.5528 - accuracy: 0.7124 - val_loss: 0.7987 - val_accuracy: 0.5314
# Epoch 9/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.4986 - accuracy: 0.7540 - val_loss: 0.9057 - val_accuracy: 0.5350
# Epoch 10/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.4350 - accuracy: 0.7938 - val_loss: 1.0406 - val_accuracy: 0.5383
# Epoch 11/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.3664 - accuracy: 0.8352 - val_loss: 1.0510 - val_accuracy: 0.5346
# Epoch 12/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.2857 - accuracy: 0.8821 - val_loss: 1.1415 - val_accuracy: 0.5368
# Epoch 13/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.2303 - accuracy: 0.9107 - val_loss: 1.2815 - val_accuracy: 0.5479
# Epoch 14/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.1823 - accuracy: 0.9286 - val_loss: 1.4404 - val_accuracy: 0.5445
# Epoch 15/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.1497 - accuracy: 0.9445 - val_loss: 1.4809 - val_accuracy: 0.5391
# Epoch 16/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.1250 - accuracy: 0.9536 - val_loss: 1.6490 - val_accuracy: 0.5361
# Epoch 17/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.1092 - accuracy: 0.9627 - val_loss: 1.6456 - val_accuracy: 0.5325
# Epoch 18/100
# 110/110 [==============================] - 12s 95ms/step - loss: 0.0844 - accuracy: 0.9708 - val_loss: 1.7666 - val_accuracy: 0.5340
# Epoch 19/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.0721 - accuracy: 0.9751 - val_loss: 1.8056 - val_accuracy: 0.5393
# Epoch 20/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0622 - accuracy: 0.9802 - val_loss: 1.8801 - val_accuracy: 0.5368
# Epoch 21/100
# ...
# Epoch 96/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 3.0646 - val_accuracy: 0.5507
# Epoch 97/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 3.1472 - val_accuracy: 0.5462
# Epoch 98/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 3.2115 - val_accuracy: 0.5393
# Epoch 99/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 3.1025 - val_accuracy: 0.5393
# Epoch 100/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 2.9411 - val_accuracy: 0.5548
# 37/37 [==============================] - 2s 42ms/step - loss: 2.2561 - accuracy: 0.6096
# Validation acc: 0.6096
# Validation AUC: 0.6098
# Validation Balanced_ACC: 0.2042
# Validation AUCSK: 0.6413
# Validation MI: 0.0253
# Validation Normalized MI: 0.0367
# Validation Adjusted MI: 0.0367
# Epoch 1/100
# 110/110 [==============================] - 12s 82ms/step - loss: 0.8721 - accuracy: 0.5127 - val_loss: 0.7470 - val_accuracy: 0.5112
# Epoch 2/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.7312 - accuracy: 0.5444 - val_loss: 0.7037 - val_accuracy: 0.5041
# Epoch 3/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.7028 - accuracy: 0.5575 - val_loss: 0.6975 - val_accuracy: 0.5086
# Epoch 4/100
# 110/110 [==============================] - 10s 78ms/step - loss: 0.6795 - accuracy: 0.5830 - val_loss: 0.6867 - val_accuracy: 0.5473
# Epoch 5/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6568 - accuracy: 0.6138 - val_loss: 0.6963 - val_accuracy: 0.5342
# Epoch 6/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.6390 - accuracy: 0.6323 - val_loss: 0.6997 - val_accuracy: 0.5527
# Epoch 7/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.6141 - accuracy: 0.6597 - val_loss: 0.7351 - val_accuracy: 0.5378
# Epoch 8/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.5769 - accuracy: 0.6934 - val_loss: 0.7669 - val_accuracy: 0.5436
# Epoch 9/100
# 110/110 [==============================] - 13s 110ms/step - loss: 0.5341 - accuracy: 0.7252 - val_loss: 0.8303 - val_accuracy: 0.5430
# Epoch 10/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.4677 - accuracy: 0.7744 - val_loss: 0.9254 - val_accuracy: 0.5432
# Epoch 11/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.3970 - accuracy: 0.8185 - val_loss: 1.0347 - val_accuracy: 0.5391
# Epoch 12/100
# 110/110 [==============================] - 9s 79ms/step - loss: 0.3210 - accuracy: 0.8586 - val_loss: 1.1077 - val_accuracy: 0.5439
# Epoch 13/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.2538 - accuracy: 0.8915 - val_loss: 1.2369 - val_accuracy: 0.5380
# Epoch 14/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.1972 - accuracy: 0.9230 - val_loss: 1.3368 - val_accuracy: 0.5479
# Epoch 15/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.1485 - accuracy: 0.9462 - val_loss: 1.4807 - val_accuracy: 0.5411
# Epoch 16/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.1172 - accuracy: 0.9567 - val_loss: 1.6360 - val_accuracy: 0.5286
# Epoch 17/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0916 - accuracy: 0.9673 - val_loss: 1.7202 - val_accuracy: 0.5368
# Epoch 18/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0858 - accuracy: 0.9688 - val_loss: 1.7420 - val_accuracy: 0.5413
# Epoch 19/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0674 - accuracy: 0.9789 - val_loss: 1.7453 - val_accuracy: 0.5447
# Epoch 20/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0619 - accuracy: 0.9792 - val_loss: 1.8217 - val_accuracy: 0.5499
# Epoch 21/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0639 - accuracy: 0.9773 - val_loss: 1.9923 - val_accuracy: 0.5337
# Epoch 22/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0591 - accuracy: 0.9779 - val_loss: 2.1179 - val_accuracy: 0.5320
# Epoch 23/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0513 - accuracy: 0.9824 - val_loss: 2.0970 - val_accuracy: 0.5370
# Epoch 24/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0474 - accuracy: 0.9835 - val_loss: 2.0914 - val_accuracy: 0.5434
# Epoch 25/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.0454 - accuracy: 0.9838 - val_loss: 2.1092 - val_accuracy: 0.5359
# Epoch 26/100
# 110/110 [==============================] - 10s 78ms/step - loss: 0.0465 - accuracy: 0.9843 - val_loss: 2.2536 - val_accuracy: 0.5333
# Epoch 27/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0365 - accuracy: 0.9871 - val_loss: 2.2883 - val_accuracy: 0.5340
# Epoch 28/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0370 - accuracy: 0.9876 - val_loss: 2.2300 - val_accuracy: 0.5340
# Epoch 29/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0287 - accuracy: 0.9914 - val_loss: 2.3288 - val_accuracy: 0.5443
# Epoch 30/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 2.3940 - val_accuracy: 0.5376
# Epoch 31/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0293 - accuracy: 0.9903 - val_loss: 2.3577 - val_accuracy: 0.5398
# Epoch 32/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0300 - accuracy: 0.9895 - val_loss: 2.3523 - val_accuracy: 0.5432
# Epoch 33/100
# 110/110 [==============================] - 12s 101ms/step - loss: 0.0319 - accuracy: 0.9883 - val_loss: 2.4628 - val_accuracy: 0.5303
# Epoch 34/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.0367 - accuracy: 0.9872 - val_loss: 2.4192 - val_accuracy: 0.5342
# Epoch 35/100
# 110/110 [==============================] - 12s 99ms/step - loss: 0.0373 - accuracy: 0.9874 - val_loss: 2.4401 - val_accuracy: 0.5370
# Epoch 36/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0354 - accuracy: 0.9875 - val_loss: 2.5568 - val_accuracy: 0.5312
# Epoch 37/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0252 - accuracy: 0.9909 - val_loss: 2.4802 - val_accuracy: 0.5385
# Epoch 38/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0235 - accuracy: 0.9936 - val_loss: 2.4831 - val_accuracy: 0.5359
# Epoch 39/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0251 - accuracy: 0.9920 - val_loss: 2.6282 - val_accuracy: 0.5333
# Epoch 40/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0229 - accuracy: 0.9931 - val_loss: 2.6344 - val_accuracy: 0.5406
# Epoch 41/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 2.6267 - val_accuracy: 0.5393
# Epoch 42/100
# 110/110 [==============================] - 9s 77ms/step - loss: 0.0343 - accuracy: 0.9877 - val_loss: 2.7184 - val_accuracy: 0.5275
# Epoch 43/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0380 - accuracy: 0.9880 - val_loss: 2.6481 - val_accuracy: 0.5292
# Epoch 44/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0286 - accuracy: 0.9907 - val_loss: 2.5142 - val_accuracy: 0.5411
# Epoch 45/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.0257 - accuracy: 0.9909 - val_loss: 2.5222 - val_accuracy: 0.5325
# Epoch 46/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.0216 - accuracy: 0.9935 - val_loss: 2.7356 - val_accuracy: 0.5256
# Epoch 47/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0220 - accuracy: 0.9922 - val_loss: 2.7104 - val_accuracy: 0.5254
# Epoch 48/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 2.7189 - val_accuracy: 0.5262
# Epoch 49/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 2.5080 - val_accuracy: 0.5406
# Epoch 50/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0269 - accuracy: 0.9901 - val_loss: 2.7489 - val_accuracy: 0.5303
# Epoch 51/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0257 - accuracy: 0.9905 - val_loss: 2.7939 - val_accuracy: 0.5344
# Epoch 52/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0367 - accuracy: 0.9860 - val_loss: 2.6868 - val_accuracy: 0.5277
# Epoch 53/100
# 110/110 [==============================] - 10s 88ms/step - loss: 0.0256 - accuracy: 0.9915 - val_loss: 2.7073 - val_accuracy: 0.5316
# Epoch 54/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0267 - accuracy: 0.9905 - val_loss: 2.8275 - val_accuracy: 0.5307
# Epoch 55/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 2.7688 - val_accuracy: 0.5417
# Epoch 56/100
# 110/110 [==============================] - 10s 78ms/step - loss: 0.0186 - accuracy: 0.9931 - val_loss: 2.7510 - val_accuracy: 0.5464
# Epoch 57/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 2.7249 - val_accuracy: 0.5337
# Epoch 58/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 2.5557 - val_accuracy: 0.5340
# Epoch 59/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0185 - accuracy: 0.9936 - val_loss: 2.5608 - val_accuracy: 0.5314
# Epoch 60/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 2.7934 - val_accuracy: 0.5340
# Epoch 61/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 2.6633 - val_accuracy: 0.5275
# Epoch 62/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 2.7567 - val_accuracy: 0.5413
# Epoch 63/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 2.8411 - val_accuracy: 0.5331
# Epoch 64/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0212 - accuracy: 0.9928 - val_loss: 2.9013 - val_accuracy: 0.5320
# Epoch 65/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0243 - accuracy: 0.9926 - val_loss: 2.7959 - val_accuracy: 0.5331
# Epoch 66/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 2.7909 - val_accuracy: 0.5286
# Epoch 67/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0221 - accuracy: 0.9923 - val_loss: 2.9029 - val_accuracy: 0.5359
# Epoch 68/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 2.8067 - val_accuracy: 0.5327
# Epoch 69/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 2.8108 - val_accuracy: 0.5342
# Epoch 70/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 2.8544 - val_accuracy: 0.5344
# Epoch 71/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 2.9103 - val_accuracy: 0.5443
# Epoch 72/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 2.8632 - val_accuracy: 0.5484
# Epoch 73/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0219 - accuracy: 0.9918 - val_loss: 2.9714 - val_accuracy: 0.5411
# Epoch 74/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0173 - accuracy: 0.9932 - val_loss: 2.9155 - val_accuracy: 0.5391
# Epoch 75/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 2.9669 - val_accuracy: 0.5380
# Epoch 76/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 2.8911 - val_accuracy: 0.5374
# Epoch 77/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 2.9558 - val_accuracy: 0.5398
# Epoch 78/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0212 - accuracy: 0.9918 - val_loss: 2.9570 - val_accuracy: 0.5439
# Epoch 79/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.0189 - accuracy: 0.9928 - val_loss: 2.9396 - val_accuracy: 0.5353
# Epoch 80/100
# 110/110 [==============================] - 11s 93ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 2.9030 - val_accuracy: 0.5441
# Epoch 81/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.0176 - accuracy: 0.9941 - val_loss: 2.9479 - val_accuracy: 0.5385
# Epoch 82/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 3.0101 - val_accuracy: 0.5346
# Epoch 83/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 2.9311 - val_accuracy: 0.5333
# Epoch 84/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 2.9526 - val_accuracy: 0.5387
# Epoch 85/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0156 - accuracy: 0.9943 - val_loss: 3.0750 - val_accuracy: 0.5290
# Epoch 86/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0153 - accuracy: 0.9942 - val_loss: 2.9767 - val_accuracy: 0.5396
# Epoch 87/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 2.9539 - val_accuracy: 0.5363
# Epoch 88/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0166 - accuracy: 0.9935 - val_loss: 2.9827 - val_accuracy: 0.5359
# Epoch 89/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.0194 - accuracy: 0.9931 - val_loss: 2.9320 - val_accuracy: 0.5383
# Epoch 90/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0161 - accuracy: 0.9945 - val_loss: 2.9239 - val_accuracy: 0.5406
# Epoch 91/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0160 - accuracy: 0.9956 - val_loss: 2.9390 - val_accuracy: 0.5357
# Epoch 92/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.0273 - accuracy: 0.9909 - val_loss: 2.7966 - val_accuracy: 0.5363
# Epoch 93/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.0215 - accuracy: 0.9924 - val_loss: 2.8782 - val_accuracy: 0.5363
# Epoch 94/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 2.8756 - val_accuracy: 0.5318
# Epoch 95/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 2.9653 - val_accuracy: 0.5406
# Epoch 96/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 2.9300 - val_accuracy: 0.5355
# Epoch 97/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 2.9678 - val_accuracy: 0.5331
# Epoch 98/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 2.8902 - val_accuracy: 0.5357
# Epoch 99/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 3.0134 - val_accuracy: 0.5355
# Epoch 100/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 3.0279 - val_accuracy: 0.5378
# 37/37 [==============================] - 3s 64ms/step - loss: 2.2856 - accuracy: 0.6055
# Validation acc: 0.6055
# Validation AUC: 0.6060
# Validation Balanced_ACC: 0.2047
# Validation AUCSK: 0.6416
# Validation MI: 0.0254
# Validation Normalized MI: 0.0369
# Validation Adjusted MI: 0.0369

# %%
ACC
# Out:
# array([0.60511607, 0.59909719, 0.60404128, 0.60232157, 0.58469474,
#        0.61156493, 0.60468614, 0.60038692, 0.60963029, 0.605546  ])

# %%
print('Average Accuracy: ', np.round( ACC.mean(),4)*100) 
print('Average std: ',np.round(np.std( ACC),4)*100)
print('==============================================')
print('Average AUC: ', np.round( AUC.mean(),4)*100) 
print('Average AUC std: ',np.round(np.std( AUC),4)*100)
print('Average std: ',np.round(np.std( ACC),4)*100)
print('==============================================')
print('Average AUCSK: ', np.round( AUCSK.mean(),4)*100) 
print('Average AUCSK std: ',np.round(np.std( AUCSK),4)*100)
print('==============================================')
print('Average Balanced Accuracy: ', np.round( BACC.mean(),4)*100) 
print('Average std: ',np.round(np.std( BACC),4)*100)
print('==============================================')
print('Average MI: ', np.round( MI.mean(),4)*100) 
print('Average std: ',np.round(np.std(MI),4)*100)
print('==============================================')
print('Average Normalized MI: ', np.round( NMI.mean(),4)*100) 
print('Average std: ',np.round(np.std(NMI),4)*100)
print('==============================================')
print('Average Ajdusted MI: ', np.round( AMI.mean(),4)*100) 
print('Average std: ',np.round(np.std(AMI),4)*100)
# Out:
# Average Accuracy:  60.27
# Average std:  0.7000000000000001
# ==============================================
# Average AUC:  60.29
# Average AUC std:  0.7100000000000001
# Average std:  0.7000000000000001
# ==============================================
# Average AUCSK:  64.1
# Average AUCSK std:  0.22999999999999998
# ==============================================
# Average Balanced Accuracy:  20.44
# Average std:  0.33
# ==============================================
# Average MI:  2.4899999999999998
# Average std:  0.06
# ==============================================
# Average Normalized MI:  3.62
# Average std:  0.09
# ==============================================
# Average Ajdusted MI:  3.62
# Average std:  0.09

# %%
print('Average Accuracy: ', np.round(val_acc_goldst.mean(),4)*100) 
print('STD Accuracy: ', np.round(np.std(val_acc_goldst),4)*100)
# Out:
# Average Accuracy:  0.0
# STD Accuracy:  0.0

# %%
AUC
# Out:
# array([0.60534006, 0.59897858, 0.60440516, 0.60232759, 0.58466834,
#        0.61213171, 0.6047824 , 0.60047299, 0.60982627, 0.60599136])

# %%
print('Average AUC: ', np.round(AUC.mean(),4)*100) 
print('STD AUC: ', np.round(np.std(AUC),4)*100)
# Out:
# Average AUC:  60.29
# STD AUC:  0.7100000000000001

# %%
np.round(np.mean(AUC),4)*100
# Out:
# 60.29

# %%
    # Create the history figure
    plt.figure(figsize=(16,9))
    for i in trainHistory.history:
        plt.plot(trainHistory.history[i],label=i)
    plt.title('Model history')
    plt.legend()
    plt.grid()

# %%
val_acc_goldst.mean()
# Out:
# 0.0

# %%
AUC
# Out:
# array([0.60534006, 0.59897858, 0.60440516, 0.60232759, 0.58466834,
#        0.61213171, 0.6047824 , 0.60047299, 0.60982627, 0.60599136])

# %%
print('Average Accuracy: ', np.round( val_acc_goldst.mean(),4)*100) 
print('Average std: ',np.round(np.std( val_acc_goldst),4)*100)
# Out:
# Average Accuracy:  0.0
# Average std:  0.0

# %%
print('Average Accuracy: ', np.round( AUC.mean(),4)*100) 
print('Average std: ',np.round(np.std( AUC),4)*100)
# Out:
# Average Accuracy:  60.29
# Average std:  0.7100000000000001
