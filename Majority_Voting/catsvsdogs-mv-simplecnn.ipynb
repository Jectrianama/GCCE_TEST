# %%
import tensorflow_datasets as tfds
import tensorflow as tf

import keras
from keras.models import Sequential,Model
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,GlobalAveragePooling2D
from keras.utils.vis_utils import plot_model
from tensorflow.keras import regularizers
from keras.layers import Activation, Dropout, Flatten, Dense, Input
from keras.layers import BatchNormalization
from sklearn.metrics import roc_auc_score



import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import cv2
import os
import time
import sys

# os.chdir('/content/drive/Shareddrives/Multiple Anotators/CrowdLayer/Notebooks')
# cwd = os.getcwd()
# sys.path.append("../Models")


# from Multiple_Annotators_C import MultipleAnnotators_Classification

import sys
sys.path.insert(1, '../input/multiple-annotators-c/')
#os.chdir('/Multiple Anotators-c/')
#cwd = os.getcwd()
sys.path.append('/input/multiple-annotators-c')
from Multiple_Annotators_C import MultipleAnnotators_Classification

# seed_value= 12321 
# from numpy.random import seed
# seed(seed_value)
# tf.random.set_seed(seed_value)

# %%
train_data = tf.data.experimental.load('/kaggle/input/cat-dogs-mv/cats_dogs_MV_Tr_1')
Test_data = tf.data.experimental.load('../input/catsvsdog-ma/cats_dogs_Te')
# Out:
# 2023-02-04 13:07:06.476017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:06.670398: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:06.671506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:06.673131: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-04 13:07:06.680858: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:06.682387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:06.683565: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:09.684112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:09.685256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:09.686167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-04 13:07:09.688477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
image_count_train = tf.data.experimental.cardinality(train_data).numpy()
image_count_train
# Out:
# 18610

# %%
image_count_test = tf.data.experimental.cardinality(Test_data).numpy()
image_count_test
# Out:
# 4652

# %%
subset = 18610
train_data = train_data.take(18610)
image_count1 = tf.data.experimental.cardinality(train_data).numpy()
image_count1
# Out:
# 18610

# %%
image_count = 3000
 
val_size = int(image_count1 * 0.25)
train_ds = train_data.skip(val_size)
val_ds  = train_data.take(val_size)

# %%
image_count_val = tf.data.experimental.cardinality(val_ds).numpy()
image_count_val
# Out:
# 4652

# %%
image_count_Tr = tf.data.experimental.cardinality(train_ds).numpy()
image_count_Tr
# Out:
# 13958

# %%
classNames = ['cat', 'dog']


i = 0

fig, ax = plt.subplots(1, 7, figsize=(15,15))
 
for image,label, label2 in train_ds.take(7):
 #  print(image.shape)
 #   predictedLabel = int(predictions[i] >= 0.5)
   # print(label)
   ax[i].axis('off')
  # ax[i].set_title(classNames[label.numpy()])
   ax[i].imshow(image)
    
   i += 1
 
# plt.show()
# Out:
# 2023-02-04 13:07:10.937008: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
# shuffle and create batches before training
batch_size = 128
train_batches = train_ds.shuffle(1024).batch(batch_size)
val_batches  = val_ds.shuffle(1024).batch(batch_size)
test_batches =  Test_data.shuffle(1024).batch(batch_size)

# %%
image_count_test = tf.data.experimental.cardinality(test_batches).numpy()
image_count_test
# Out:
# 37

# %% [markdown]
# **Build the GOLD STANDARD classifier**
#
#
# This will look familiar to you because it is almost identical to the previous model we built. The key difference is the output is just one unit that is sigmoid activated. This is because we're only dealing with two classes.

# %%
def build_base_model():
    # base_model = Sequential()


    # base_model.add( Conv2D(32, (3, 3), activation='relu',
    # input_shape=(150, 150, 3)))
    # base_model.add( MaxPooling2D((2, 2)))
    # base_model.add( Dropout(0.2))

    # base_model.add( Conv2D(64, (3, 3), activation='relu'))
    # base_model.add( MaxPooling2D((2, 2)))
    # base_model.add( Dropout(0.2))

    # base_model.add( Conv2D(128, (3, 3), activation='relu'))
    # base_model.add( MaxPooling2D((2, 2)))
    # base_model.add(Dropout(0.2))

    # base_model.add(Conv2D(256, (3, 3), activation='relu'))
    # base_model.add(MaxPooling2D((2, 2)))
    # base_model.add(Dropout(0.2))

    # base_model.add(Flatten())


    # base_model.add(Dense(256, activation='relu'))
    # base_model.add(Dense(1, activation='sigmoid'))

  
    base_model = Sequential()
    base_model.add(BatchNormalization())
    base_model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))
   
    base_model.add(BatchNormalization())
    base_model.add(Conv2D(32, (3, 3)))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))
    

    base_model.add(BatchNormalization())
    base_model.add(Conv2D(64, (3, 3)))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))

    base_model.add(BatchNormalization())
    base_model.add(Conv2D(64, (3, 3)))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(MaxPooling2D(pool_size=(2, 2)))
   # base_model.add(Dropout(0.2))


    base_model.add(Flatten()) 
    base_model.add(BatchNormalization())
    base_model.add(Dense(128))
    base_model.add(Activation('relu'))
    base_model.add(BatchNormalization())
    base_model.add(Dropout(0.2))
    base_model.add(Dense(N_CLASSES))
    base_model.add(Activation('softmax'))

    base_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3, clipnorm = 1.0), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return base_model

# %%
N_CLASSES = 2
def one_hot(image, ytrue, label):
    one_hot_targets = label  # tf.one_hot(tf.cast(label, tf.int32), N_CLASSES, axis = 1, dtype=tf.int32)
    return image, one_hot_targets

# %%
train_batches_MV = train_batches.map(one_hot)

# %%
val_batches_MV = val_batches.map(one_hot)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model1.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
#y_test= np.asarray([aux[1].numpy() for aux  in Test_data ])
#X_test = np.asarray([aux[0].numpy() for aux  in Test_data ])

# %%
K=2
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import normalized_mutual_info_score, mutual_info_score, adjusted_mutual_info_score
#l1 =0.0001
NUM_RUNS = 10
N_EPOCHS = 100
ACC = np.zeros(NUM_RUNS)
AUC = np.zeros(NUM_RUNS)
MI = np.zeros(NUM_RUNS)
NMI = np.zeros(NUM_RUNS)
AMI = np.zeros(NUM_RUNS)
BACC = np.zeros(NUM_RUNS)
BACC1 = []
MI1 = []
NMI1 =[]
AMI1 = []
val_acc_goldst = np.zeros(NUM_RUNS)
AUC= np.zeros(NUM_RUNS)
for i in range(NUM_RUNS):
    model = build_base_model()  
    trainHistory = model.fit(train_batches_MV, validation_data= val_batches_MV, epochs=N_EPOCHS,  callbacks=callbacks)
    (loss, accuracy) = model.evaluate(test_batches)
    #Accurarcy =================
    ACC[i] = accuracy
    print("Validation acc: %.4f" % (float(ACC[i]),))
 
    #AUC =======================
    val_AUC_metric = tf.keras.metrics.AUC( from_logits = True)
    for x_batch_val, y_batch_val in test_batches:
        val_logits = model(x_batch_val.numpy(), training=False)
       # tf.print(y_batch_val)
        val_AUC_metric.update_state(y_batch_val, val_logits.numpy().argmax(axis=1).astype('float'))   #val_logits[:,Y.shape[1]:].argmax(axis=1).astype('float'))
        val_AUC_metric.update_state(y_batch_val, val_logits[:,:K].numpy().argmax(axis=1).astype('float'))
        BACC1.append(balanced_accuracy_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze(), adjusted=True))
        MI1.append(mutual_info_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze()))
        NMI1.append(normalized_mutual_info_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze()))
        AMI1.append(normalized_mutual_info_score(y_batch_val.numpy().squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze()))


    val_AUC = val_AUC_metric.result()
    val_AUC_metric.reset_states()
    val_AUC = val_AUC.numpy()
    print("Validation AUC: %.4f" % (float(val_AUC),))
    AUC[i] = val_AUC
    #===================================================
    # balanced. Accurcy
    BACC[i] = np.array(BACC1).mean() # balanced_accuracy_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze(), adjusted=True)
    print("Validation Balanced_ACC: %.4f" % (float(BACC[i])))

    #MI

    MI[i] =  np.array(MI1).mean()  #mutual_info_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze())
    print("Validation MI: %.4f" % (float(MI[i]),))
    NMI[i] =  np.array(NMI1).mean()   #normalized_mutual_info_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze())
    print("Validation Normalized MI: %.4f" % (float(NMI[i]),))
    AMI[i]= np.array(AMI1).mean()  #adjusted_mutual_info_score(Y_true_test.squeeze(), val_logits[:,:K].numpy().argmax(axis=1).squeeze())
    print("Validation Adjusted MI: %.4f" % (float(AMI[i]),))

    
    
    # Create the history figure
    plt.figure(figsize=(16,9))
    for i in trainHistory.history:
        plt.plot(trainHistory.history[i],label=i)
    plt.title('Model history')
    plt.legend()
    plt.grid()
import pandas as pd

df_gold = pd.DataFrame(val_acc_goldst)
df_gold.to_csv('/kaggle/working/CatDogs_MA_VGG19_GOLD.csv',index=False) # save to notebook output
  

# plt.plot(trainHistory.history['accuracy'])
# plt.plot(trainHistory.history['val_accuracy'])
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Training', 'Validation'])
# plt.grid()
# plt.show()
# Out:
# Epoch 1/100
# 2023-02-04 13:07:36.820844: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 110/110 [==============================] - 64s 440ms/step - loss: 0.8475 - accuracy: 0.5234 - val_loss: 0.7023 - val_accuracy: 0.4886
#
# Epoch 00001: val_loss improved from inf to 0.70234, saving model to model1.h5
# Epoch 2/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.7402 - accuracy: 0.5287 - val_loss: 0.7016 - val_accuracy: 0.5112
#
# Epoch 00002: val_loss improved from 0.70234 to 0.70155, saving model to model1.h5
# Epoch 3/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.7068 - accuracy: 0.5494 - val_loss: 0.6970 - val_accuracy: 0.5101
#
# Epoch 00003: val_loss improved from 0.70155 to 0.69698, saving model to model1.h5
# Epoch 4/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.6917 - accuracy: 0.5707 - val_loss: 0.7064 - val_accuracy: 0.5273
#
# Epoch 00004: val_loss did not improve from 0.69698
# Epoch 5/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6794 - accuracy: 0.5830 - val_loss: 0.6902 - val_accuracy: 0.5432
#
# Epoch 00005: val_loss improved from 0.69698 to 0.69020, saving model to model1.h5
# Epoch 6/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.6574 - accuracy: 0.6037 - val_loss: 0.6931 - val_accuracy: 0.5507
#
# Epoch 00006: val_loss did not improve from 0.69020
# Epoch 7/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.6420 - accuracy: 0.6294 - val_loss: 0.7063 - val_accuracy: 0.5451
#
# Epoch 00007: val_loss did not improve from 0.69020
# Epoch 8/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.6203 - accuracy: 0.6520 - val_loss: 0.7123 - val_accuracy: 0.5488
#
# Epoch 00008: val_loss did not improve from 0.69020
# Epoch 9/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.5855 - accuracy: 0.6865 - val_loss: 0.7448 - val_accuracy: 0.5475
#
# Epoch 00009: val_loss did not improve from 0.69020
# Epoch 10/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.5411 - accuracy: 0.7238 - val_loss: 0.8396 - val_accuracy: 0.5430
#
# Epoch 00010: val_loss did not improve from 0.69020
# Epoch 11/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.4819 - accuracy: 0.7647 - val_loss: 0.8910 - val_accuracy: 0.5447
#
# Epoch 00011: val_loss did not improve from 0.69020
# Epoch 12/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.4076 - accuracy: 0.8101 - val_loss: 0.9948 - val_accuracy: 0.5464
#
# Epoch 00012: val_loss did not improve from 0.69020
# Epoch 13/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.3316 - accuracy: 0.8539 - val_loss: 1.1712 - val_accuracy: 0.5421
#
# Epoch 00013: val_loss did not improve from 0.69020
# Epoch 14/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.2591 - accuracy: 0.8925 - val_loss: 1.3088 - val_accuracy: 0.5466
#
# Epoch 00014: val_loss did not improve from 0.69020
# Epoch 15/100
# 110/110 [==============================] - 11s 93ms/step - loss: 0.2048 - accuracy: 0.9195 - val_loss: 1.3899 - val_accuracy: 0.5460
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.69020
# Epoch 00015: early stopping
# 37/37 [==============================] - 26s 342ms/step - loss: 1.2272 - accuracy: 0.5776
# Validation acc: 0.5776
# Validation AUC: 0.5764
# Validation Balanced_ACC: 0.1537
# Validation MI: 0.0152
# Validation Normalized MI: 0.0222
# Validation Adjusted MI: 0.0222
# Epoch 1/100
# 110/110 [==============================] - 21s 148ms/step - loss: 0.8647 - accuracy: 0.5261 - val_loss: 0.7898 - val_accuracy: 0.5112
#
# Epoch 00001: val_loss did not improve from 0.69020
# Epoch 2/100
# 110/110 [==============================] - 14s 95ms/step - loss: 0.7293 - accuracy: 0.5413 - val_loss: 0.7371 - val_accuracy: 0.5110
#
# Epoch 00002: val_loss did not improve from 0.69020
# Epoch 3/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.7028 - accuracy: 0.5618 - val_loss: 0.7135 - val_accuracy: 0.5112
#
# Epoch 00003: val_loss did not improve from 0.69020
# Epoch 4/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6805 - accuracy: 0.5873 - val_loss: 0.6904 - val_accuracy: 0.5387
#
# Epoch 00004: val_loss did not improve from 0.69020
# Epoch 5/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.6617 - accuracy: 0.6097 - val_loss: 0.6904 - val_accuracy: 0.5535
#
# Epoch 00005: val_loss did not improve from 0.69020
# Epoch 6/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.6425 - accuracy: 0.6282 - val_loss: 0.7028 - val_accuracy: 0.5585
#
# Epoch 00006: val_loss did not improve from 0.69020
# Epoch 7/100
# 110/110 [==============================] - 11s 92ms/step - loss: 0.6188 - accuracy: 0.6543 - val_loss: 0.7135 - val_accuracy: 0.5522
#
# Epoch 00007: val_loss did not improve from 0.69020
# Epoch 8/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.5883 - accuracy: 0.6838 - val_loss: 0.7336 - val_accuracy: 0.5580
#
# Epoch 00008: val_loss did not improve from 0.69020
# Epoch 9/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.5471 - accuracy: 0.7205 - val_loss: 0.7805 - val_accuracy: 0.5512
#
# Epoch 00009: val_loss did not improve from 0.69020
# Epoch 10/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.4929 - accuracy: 0.7591 - val_loss: 0.8660 - val_accuracy: 0.5475
#
# Epoch 00010: val_loss did not improve from 0.69020
# Epoch 11/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.4232 - accuracy: 0.7998 - val_loss: 0.9482 - val_accuracy: 0.5540
#
# Epoch 00011: val_loss did not improve from 0.69020
# Epoch 12/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.3632 - accuracy: 0.8383 - val_loss: 0.9908 - val_accuracy: 0.5550
#
# Epoch 00012: val_loss did not improve from 0.69020
# Epoch 13/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.2909 - accuracy: 0.8749 - val_loss: 1.1258 - val_accuracy: 0.5460
#
# Epoch 00013: val_loss did not improve from 0.69020
# Epoch 14/100
# 110/110 [==============================] - 11s 94ms/step - loss: 0.2321 - accuracy: 0.9026 - val_loss: 1.3239 - val_accuracy: 0.5400
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00014: val_loss did not improve from 0.69020
# Epoch 00014: early stopping
# 37/37 [==============================] - 3s 65ms/step - loss: 1.1777 - accuracy: 0.5845
# Validation acc: 0.5845
# Validation AUC: 0.5847
# Validation Balanced_ACC: 0.1606
# Validation MI: 0.0169
# Validation Normalized MI: 0.0245
# Validation Adjusted MI: 0.0245
# Epoch 1/100
# 110/110 [==============================] - 12s 83ms/step - loss: 0.8741 - accuracy: 0.5268 - val_loss: 0.7118 - val_accuracy: 0.5131
#
# Epoch 00001: val_loss did not improve from 0.69020
# Epoch 2/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.7309 - accuracy: 0.5403 - val_loss: 0.7302 - val_accuracy: 0.5084
#
# Epoch 00002: val_loss did not improve from 0.69020
# Epoch 3/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.7095 - accuracy: 0.5635 - val_loss: 0.6968 - val_accuracy: 0.5159
#
# Epoch 00003: val_loss did not improve from 0.69020
# Epoch 4/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.6830 - accuracy: 0.5896 - val_loss: 0.7037 - val_accuracy: 0.5299
#
# Epoch 00004: val_loss did not improve from 0.69020
# Epoch 5/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.6622 - accuracy: 0.6096 - val_loss: 0.7008 - val_accuracy: 0.5413
#
# Epoch 00005: val_loss did not improve from 0.69020
# Epoch 6/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6406 - accuracy: 0.6325 - val_loss: 0.7018 - val_accuracy: 0.5486
#
# Epoch 00006: val_loss did not improve from 0.69020
# Epoch 7/100
# 110/110 [==============================] - 12s 96ms/step - loss: 0.6115 - accuracy: 0.6652 - val_loss: 0.7352 - val_accuracy: 0.5531
#
# Epoch 00007: val_loss did not improve from 0.69020
# Epoch 8/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.5775 - accuracy: 0.6929 - val_loss: 0.7664 - val_accuracy: 0.5449
#
# Epoch 00008: val_loss did not improve from 0.69020
# Epoch 9/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.5252 - accuracy: 0.7292 - val_loss: 0.8134 - val_accuracy: 0.5344
#
# Epoch 00009: val_loss did not improve from 0.69020
# Epoch 10/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.4656 - accuracy: 0.7735 - val_loss: 0.8773 - val_accuracy: 0.5374
#
# Epoch 00010: val_loss did not improve from 0.69020
# Epoch 11/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.4017 - accuracy: 0.8134 - val_loss: 0.9561 - val_accuracy: 0.5284
#
# Epoch 00011: val_loss did not improve from 0.69020
# Epoch 12/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.3220 - accuracy: 0.8615 - val_loss: 1.0559 - val_accuracy: 0.5355
#
# Epoch 00012: val_loss did not improve from 0.69020
# Epoch 13/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.2588 - accuracy: 0.8920 - val_loss: 1.2551 - val_accuracy: 0.5430
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00013: val_loss did not improve from 0.69020
# Epoch 00013: early stopping
# 37/37 [==============================] - 3s 70ms/step - loss: 1.0541 - accuracy: 0.5821
# Validation acc: 0.5821
# Validation AUC: 0.5819
# Validation Balanced_ACC: 0.1620
# Validation MI: 0.0167
# Validation Normalized MI: 0.0243
# Validation Adjusted MI: 0.0243
# Epoch 1/100
# 110/110 [==============================] - 12s 83ms/step - loss: 0.8679 - accuracy: 0.5180 - val_loss: 0.7430 - val_accuracy: 0.5112
#
# Epoch 00001: val_loss did not improve from 0.69020
# Epoch 2/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.7335 - accuracy: 0.5422 - val_loss: 0.7038 - val_accuracy: 0.4933
#
# Epoch 00002: val_loss did not improve from 0.69020
# Epoch 3/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.7036 - accuracy: 0.5608 - val_loss: 0.7008 - val_accuracy: 0.4875
#
# Epoch 00003: val_loss did not improve from 0.69020
# Epoch 4/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6826 - accuracy: 0.5809 - val_loss: 0.6953 - val_accuracy: 0.5236
#
# Epoch 00004: val_loss did not improve from 0.69020
# Epoch 5/100
# 110/110 [==============================] - 12s 98ms/step - loss: 0.6660 - accuracy: 0.6004 - val_loss: 0.6949 - val_accuracy: 0.5348
#
# Epoch 00005: val_loss did not improve from 0.69020
# Epoch 6/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.6465 - accuracy: 0.6244 - val_loss: 0.6972 - val_accuracy: 0.5578
#
# Epoch 00006: val_loss did not improve from 0.69020
# Epoch 7/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.6229 - accuracy: 0.6509 - val_loss: 0.7086 - val_accuracy: 0.5469
#
# Epoch 00007: val_loss did not improve from 0.69020
# Epoch 8/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.5960 - accuracy: 0.6721 - val_loss: 0.7402 - val_accuracy: 0.5454
#
# Epoch 00008: val_loss did not improve from 0.69020
# Epoch 9/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.5541 - accuracy: 0.7095 - val_loss: 0.8322 - val_accuracy: 0.5488
#
# Epoch 00009: val_loss did not improve from 0.69020
# Epoch 10/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.4940 - accuracy: 0.7525 - val_loss: 0.8731 - val_accuracy: 0.5479
#
# Epoch 00010: val_loss did not improve from 0.69020
# Epoch 11/100
# 110/110 [==============================] - 11s 87ms/step - loss: 0.4426 - accuracy: 0.7837 - val_loss: 0.9238 - val_accuracy: 0.5411
#
# Epoch 00011: val_loss did not improve from 0.69020
# Epoch 12/100
# 110/110 [==============================] - 11s 86ms/step - loss: 0.3628 - accuracy: 0.8354 - val_loss: 1.0856 - val_accuracy: 0.5436
#
# Epoch 00012: val_loss did not improve from 0.69020
# Epoch 13/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.3027 - accuracy: 0.8685 - val_loss: 1.1845 - val_accuracy: 0.5475
#
# Epoch 00013: val_loss did not improve from 0.69020
# Epoch 14/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.2347 - accuracy: 0.9048 - val_loss: 1.3069 - val_accuracy: 0.5406
#
# Epoch 00014: val_loss did not improve from 0.69020
# Epoch 15/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.1802 - accuracy: 0.9314 - val_loss: 1.3934 - val_accuracy: 0.5490
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.69020
# Epoch 00015: early stopping
# 37/37 [==============================] - 3s 59ms/step - loss: 1.1856 - accuracy: 0.5935
# Validation acc: 0.5935
# Validation AUC: 0.5939
# Validation Balanced_ACC: 0.1681
# Validation MI: 0.0176
# Validation Normalized MI: 0.0256
# Validation Adjusted MI: 0.0256
# Epoch 1/100
# 110/110 [==============================] - 12s 88ms/step - loss: 0.8583 - accuracy: 0.5282 - val_loss: 0.7081 - val_accuracy: 0.5099
#
# Epoch 00001: val_loss did not improve from 0.69020
# Epoch 2/100
# 110/110 [==============================] - 12s 97ms/step - loss: 0.7317 - accuracy: 0.5426 - val_loss: 0.6962 - val_accuracy: 0.5056
#
# Epoch 00002: val_loss did not improve from 0.69020
# Epoch 3/100
# 110/110 [==============================] - 11s 91ms/step - loss: 0.7094 - accuracy: 0.5595 - val_loss: 0.6984 - val_accuracy: 0.5181
#
# Epoch 00003: val_loss did not improve from 0.69020
# Epoch 4/100
# 110/110 [==============================] - 11s 84ms/step - loss: 0.6847 - accuracy: 0.5820 - val_loss: 0.6889 - val_accuracy: 0.5432
#
# Epoch 00004: val_loss improved from 0.69020 to 0.68890, saving model to model1.h5
# Epoch 5/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6665 - accuracy: 0.5959 - val_loss: 0.6925 - val_accuracy: 0.5587
#
# Epoch 00005: val_loss did not improve from 0.68890
# Epoch 6/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.6436 - accuracy: 0.6281 - val_loss: 0.6965 - val_accuracy: 0.5477
#
# Epoch 00006: val_loss did not improve from 0.68890
# Epoch 7/100
# 110/110 [==============================] - 12s 95ms/step - loss: 0.6252 - accuracy: 0.6442 - val_loss: 0.7243 - val_accuracy: 0.5290
#
# Epoch 00007: val_loss did not improve from 0.68890
# Epoch 8/100
# 110/110 [==============================] - 10s 78ms/step - loss: 0.5937 - accuracy: 0.6752 - val_loss: 0.7633 - val_accuracy: 0.5393
#
# Epoch 00008: val_loss did not improve from 0.68890
# Epoch 9/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.5517 - accuracy: 0.7117 - val_loss: 0.7923 - val_accuracy: 0.5473
#
# Epoch 00009: val_loss did not improve from 0.68890
# Epoch 10/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.4986 - accuracy: 0.7511 - val_loss: 0.8922 - val_accuracy: 0.5380
#
# Epoch 00010: val_loss did not improve from 0.68890
# Epoch 11/100
# 110/110 [==============================] - 11s 92ms/step - loss: 0.4313 - accuracy: 0.7979 - val_loss: 0.9338 - val_accuracy: 0.5428
#
# Epoch 00011: val_loss did not improve from 0.68890
# Epoch 12/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.3560 - accuracy: 0.8420 - val_loss: 1.0159 - val_accuracy: 0.5466
#
# Epoch 00012: val_loss did not improve from 0.68890
# Epoch 13/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.2876 - accuracy: 0.8781 - val_loss: 1.1175 - val_accuracy: 0.5445
#
# Epoch 00013: val_loss did not improve from 0.68890
# Epoch 14/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.2268 - accuracy: 0.9081 - val_loss: 1.2611 - val_accuracy: 0.5464
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00014: val_loss did not improve from 0.68890
# Epoch 00014: early stopping
# 37/37 [==============================] - 3s 63ms/step - loss: 1.1224 - accuracy: 0.5838
# Validation acc: 0.5838
# Validation AUC: 0.5845
# Validation Balanced_ACC: 0.1680
# Validation MI: 0.0175
# Validation Normalized MI: 0.0254
# Validation Adjusted MI: 0.0254
# Epoch 1/100
# 110/110 [==============================] - 12s 85ms/step - loss: 0.8313 - accuracy: 0.5168 - val_loss: 0.7494 - val_accuracy: 0.5112
#
# Epoch 00001: val_loss did not improve from 0.68890
# Epoch 2/100
# 110/110 [==============================] - 11s 93ms/step - loss: 0.7315 - accuracy: 0.5333 - val_loss: 0.7051 - val_accuracy: 0.5015
#
# Epoch 00002: val_loss did not improve from 0.68890
# Epoch 3/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.7042 - accuracy: 0.5506 - val_loss: 0.7029 - val_accuracy: 0.5234
#
# Epoch 00003: val_loss did not improve from 0.68890
# Epoch 4/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.6894 - accuracy: 0.5681 - val_loss: 0.6857 - val_accuracy: 0.5525
#
# Epoch 00004: val_loss improved from 0.68890 to 0.68569, saving model to model1.h5
# Epoch 5/100
# 110/110 [==============================] - 11s 96ms/step - loss: 0.6732 - accuracy: 0.5886 - val_loss: 0.6780 - val_accuracy: 0.5677
#
# Epoch 00005: val_loss improved from 0.68569 to 0.67797, saving model to model1.h5
# Epoch 6/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6587 - accuracy: 0.6045 - val_loss: 0.6941 - val_accuracy: 0.5604
#
# Epoch 00006: val_loss did not improve from 0.67797
# Epoch 7/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.6392 - accuracy: 0.6343 - val_loss: 0.6958 - val_accuracy: 0.5525
#
# Epoch 00007: val_loss did not improve from 0.67797
# Epoch 8/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.6162 - accuracy: 0.6564 - val_loss: 0.7036 - val_accuracy: 0.5651
#
# Epoch 00008: val_loss did not improve from 0.67797
# Epoch 9/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.5782 - accuracy: 0.6890 - val_loss: 0.7640 - val_accuracy: 0.5353
#
# Epoch 00009: val_loss did not improve from 0.67797
# Epoch 10/100
# 110/110 [==============================] - 11s 94ms/step - loss: 0.5316 - accuracy: 0.7285 - val_loss: 0.8218 - val_accuracy: 0.5402
#
# Epoch 00010: val_loss did not improve from 0.67797
# Epoch 11/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.4723 - accuracy: 0.7716 - val_loss: 0.9110 - val_accuracy: 0.5417
#
# Epoch 00011: val_loss did not improve from 0.67797
# Epoch 12/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.3944 - accuracy: 0.8185 - val_loss: 1.0110 - val_accuracy: 0.5546
#
# Epoch 00012: val_loss did not improve from 0.67797
# Epoch 13/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.3258 - accuracy: 0.8575 - val_loss: 1.1722 - val_accuracy: 0.5486
#
# Epoch 00013: val_loss did not improve from 0.67797
# Epoch 14/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.2462 - accuracy: 0.9002 - val_loss: 1.2063 - val_accuracy: 0.5462
#
# Epoch 00014: val_loss did not improve from 0.67797
# Epoch 15/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.1794 - accuracy: 0.9297 - val_loss: 1.4109 - val_accuracy: 0.5380
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.67797
# Epoch 00015: early stopping
# 37/37 [==============================] - 13s 50ms/step - loss: 1.2949 - accuracy: 0.5795
# Validation acc: 0.5795
# Validation AUC: 0.5812
# Validation Balanced_ACC: 0.1669
# Validation MI: 0.0172
# Validation Normalized MI: 0.0250
# Validation Adjusted MI: 0.0250
# Epoch 1/100
# 110/110 [==============================] - 12s 84ms/step - loss: 0.8494 - accuracy: 0.5239 - val_loss: 0.7051 - val_accuracy: 0.5110
#
# Epoch 00001: val_loss did not improve from 0.67797
# Epoch 2/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.7208 - accuracy: 0.5488 - val_loss: 0.6968 - val_accuracy: 0.4998
#
# Epoch 00002: val_loss did not improve from 0.67797
# Epoch 3/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.7017 - accuracy: 0.5607 - val_loss: 0.6992 - val_accuracy: 0.5129
#
# Epoch 00003: val_loss did not improve from 0.67797
# Epoch 4/100
# 110/110 [==============================] - 10s 78ms/step - loss: 0.6811 - accuracy: 0.5815 - val_loss: 0.7169 - val_accuracy: 0.5224
#
# Epoch 00004: val_loss did not improve from 0.67797
# Epoch 5/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.6604 - accuracy: 0.6050 - val_loss: 0.6984 - val_accuracy: 0.5499
#
# Epoch 00005: val_loss did not improve from 0.67797
# Epoch 6/100
# 110/110 [==============================] - 10s 87ms/step - loss: 0.6370 - accuracy: 0.6373 - val_loss: 0.7044 - val_accuracy: 0.5471
#
# Epoch 00006: val_loss did not improve from 0.67797
# Epoch 7/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6049 - accuracy: 0.6603 - val_loss: 0.7167 - val_accuracy: 0.5466
#
# Epoch 00007: val_loss did not improve from 0.67797
# Epoch 8/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.5674 - accuracy: 0.6983 - val_loss: 0.7597 - val_accuracy: 0.5402
#
# Epoch 00008: val_loss did not improve from 0.67797
# Epoch 9/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.5096 - accuracy: 0.7478 - val_loss: 0.8192 - val_accuracy: 0.5372
#
# Epoch 00009: val_loss did not improve from 0.67797
# Epoch 10/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.4342 - accuracy: 0.7990 - val_loss: 0.9535 - val_accuracy: 0.5421
#
# Epoch 00010: val_loss did not improve from 0.67797
# Epoch 11/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.3520 - accuracy: 0.8428 - val_loss: 1.0913 - val_accuracy: 0.5342
#
# Epoch 00011: val_loss did not improve from 0.67797
# Epoch 12/100
# 110/110 [==============================] - 11s 89ms/step - loss: 0.2929 - accuracy: 0.8741 - val_loss: 1.1769 - val_accuracy: 0.5353
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00012: val_loss did not improve from 0.67797
# Epoch 00012: early stopping
# 37/37 [==============================] - 2s 45ms/step - loss: 1.0510 - accuracy: 0.5671
# Validation acc: 0.5671
# Validation AUC: 0.5681
# Validation Balanced_ACC: 0.1630
# Validation MI: 0.0167
# Validation Normalized MI: 0.0242
# Validation Adjusted MI: 0.0242
# Epoch 1/100
# 110/110 [==============================] - 16s 123ms/step - loss: 0.8292 - accuracy: 0.5250 - val_loss: 0.7404 - val_accuracy: 0.4888
#
# Epoch 00001: val_loss did not improve from 0.67797
# Epoch 2/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.7169 - accuracy: 0.5434 - val_loss: 0.7011 - val_accuracy: 0.5052
#
# Epoch 00002: val_loss did not improve from 0.67797
# Epoch 3/100
# 110/110 [==============================] - 12s 99ms/step - loss: 0.6980 - accuracy: 0.5631 - val_loss: 0.7018 - val_accuracy: 0.4981
#
# Epoch 00003: val_loss did not improve from 0.67797
# Epoch 4/100
# 110/110 [==============================] - 14s 115ms/step - loss: 0.6786 - accuracy: 0.5849 - val_loss: 0.6927 - val_accuracy: 0.5258
#
# Epoch 00004: val_loss did not improve from 0.67797
# Epoch 5/100
# 110/110 [==============================] - 12s 100ms/step - loss: 0.6651 - accuracy: 0.6002 - val_loss: 0.6981 - val_accuracy: 0.5400
#
# Epoch 00005: val_loss did not improve from 0.67797
# Epoch 6/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.6402 - accuracy: 0.6323 - val_loss: 0.7012 - val_accuracy: 0.5486
#
# Epoch 00006: val_loss did not improve from 0.67797
# Epoch 7/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.6189 - accuracy: 0.6563 - val_loss: 0.7113 - val_accuracy: 0.5557
#
# Epoch 00007: val_loss did not improve from 0.67797
# Epoch 8/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.5860 - accuracy: 0.6846 - val_loss: 0.7609 - val_accuracy: 0.5477
#
# Epoch 00008: val_loss did not improve from 0.67797
# Epoch 9/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.5421 - accuracy: 0.7187 - val_loss: 0.8108 - val_accuracy: 0.5439
#
# Epoch 00009: val_loss did not improve from 0.67797
# Epoch 10/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.4881 - accuracy: 0.7652 - val_loss: 0.8787 - val_accuracy: 0.5490
#
# Epoch 00010: val_loss did not improve from 0.67797
# Epoch 11/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.4143 - accuracy: 0.8080 - val_loss: 0.9557 - val_accuracy: 0.5488
#
# Epoch 00011: val_loss did not improve from 0.67797
# Epoch 12/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.3480 - accuracy: 0.8451 - val_loss: 1.0673 - val_accuracy: 0.5406
#
# Epoch 00012: val_loss did not improve from 0.67797
# Epoch 13/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.2835 - accuracy: 0.8816 - val_loss: 1.1691 - val_accuracy: 0.5482
#
# Epoch 00013: val_loss did not improve from 0.67797
# Epoch 14/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.2129 - accuracy: 0.9155 - val_loss: 1.2986 - val_accuracy: 0.5451
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00014: val_loss did not improve from 0.67797
# Epoch 00014: early stopping
# 37/37 [==============================] - 4s 60ms/step - loss: 1.0942 - accuracy: 0.5991
# Validation acc: 0.5991
# Validation AUC: 0.5977
# Validation Balanced_ACC: 0.1669
# Validation MI: 0.0174
# Validation Normalized MI: 0.0254
# Validation Adjusted MI: 0.0254
# Epoch 1/100
# 110/110 [==============================] - 11s 81ms/step - loss: 0.8550 - accuracy: 0.5263 - val_loss: 0.7039 - val_accuracy: 0.4970
#
# Epoch 00001: val_loss did not improve from 0.67797
# Epoch 2/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.7254 - accuracy: 0.5474 - val_loss: 0.6990 - val_accuracy: 0.4942
#
# Epoch 00002: val_loss did not improve from 0.67797
# Epoch 3/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.7081 - accuracy: 0.5532 - val_loss: 0.7004 - val_accuracy: 0.5101
#
# Epoch 00003: val_loss did not improve from 0.67797
# Epoch 4/100
# 110/110 [==============================] - 10s 86ms/step - loss: 0.6791 - accuracy: 0.5860 - val_loss: 0.6981 - val_accuracy: 0.5288
#
# Epoch 00004: val_loss did not improve from 0.67797
# Epoch 5/100
# 110/110 [==============================] - 12s 99ms/step - loss: 0.6662 - accuracy: 0.6021 - val_loss: 0.6928 - val_accuracy: 0.5383
#
# Epoch 00005: val_loss did not improve from 0.67797
# Epoch 6/100
# 110/110 [==============================] - 10s 81ms/step - loss: 0.6477 - accuracy: 0.6244 - val_loss: 0.7002 - val_accuracy: 0.5432
#
# Epoch 00006: val_loss did not improve from 0.67797
# Epoch 7/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.6162 - accuracy: 0.6582 - val_loss: 0.7115 - val_accuracy: 0.5572
#
# Epoch 00007: val_loss did not improve from 0.67797
# Epoch 8/100
# 110/110 [==============================] - 20s 170ms/step - loss: 0.5843 - accuracy: 0.6841 - val_loss: 0.7763 - val_accuracy: 0.5466
#
# Epoch 00008: val_loss did not improve from 0.67797
# Epoch 9/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.5332 - accuracy: 0.7283 - val_loss: 0.8160 - val_accuracy: 0.5509
#
# Epoch 00009: val_loss did not improve from 0.67797
# Epoch 10/100
# 110/110 [==============================] - 50s 449ms/step - loss: 0.4765 - accuracy: 0.7708 - val_loss: 0.8597 - val_accuracy: 0.5565
#
# Epoch 00010: val_loss did not improve from 0.67797
# Epoch 11/100
# 110/110 [==============================] - 22s 172ms/step - loss: 0.3940 - accuracy: 0.8137 - val_loss: 0.9740 - val_accuracy: 0.5469
#
# Epoch 00011: val_loss did not improve from 0.67797
# Epoch 12/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.3240 - accuracy: 0.8590 - val_loss: 1.0681 - val_accuracy: 0.5419
#
# Epoch 00012: val_loss did not improve from 0.67797
# Epoch 13/100
# 110/110 [==============================] - 11s 95ms/step - loss: 0.2495 - accuracy: 0.8986 - val_loss: 1.1883 - val_accuracy: 0.5421
#
# Epoch 00013: val_loss did not improve from 0.67797
# Epoch 14/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.1964 - accuracy: 0.9228 - val_loss: 1.3818 - val_accuracy: 0.5368
#
# Epoch 00014: val_loss did not improve from 0.67797
# Epoch 15/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.1618 - accuracy: 0.9389 - val_loss: 1.4038 - val_accuracy: 0.5451
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.67797
# Epoch 00015: early stopping
# 37/37 [==============================] - 12s 228ms/step - loss: 1.2336 - accuracy: 0.5914
# Validation acc: 0.5914
# Validation AUC: 0.5920
# Validation Balanced_ACC: 0.1689
# Validation MI: 0.0179
# Validation Normalized MI: 0.0261
# Validation Adjusted MI: 0.0261
# Epoch 1/100
# 110/110 [==============================] - 11s 78ms/step - loss: 0.8778 - accuracy: 0.5242 - val_loss: 0.9825 - val_accuracy: 0.5112
#
# Epoch 00001: val_loss did not improve from 0.67797
# Epoch 2/100
# 110/110 [==============================] - 11s 88ms/step - loss: 0.7345 - accuracy: 0.5447 - val_loss: 0.7049 - val_accuracy: 0.4933
#
# Epoch 00002: val_loss did not improve from 0.67797
# Epoch 3/100
# 110/110 [==============================] - 11s 93ms/step - loss: 0.7039 - accuracy: 0.5608 - val_loss: 0.7411 - val_accuracy: 0.4959
#
# Epoch 00003: val_loss did not improve from 0.67797
# Epoch 4/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.6844 - accuracy: 0.5761 - val_loss: 0.7381 - val_accuracy: 0.5120
#
# Epoch 00004: val_loss did not improve from 0.67797
# Epoch 5/100
# 110/110 [==============================] - 9s 79ms/step - loss: 0.6653 - accuracy: 0.6035 - val_loss: 0.6937 - val_accuracy: 0.5451
#
# Epoch 00005: val_loss did not improve from 0.67797
# Epoch 6/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.6403 - accuracy: 0.6260 - val_loss: 0.7043 - val_accuracy: 0.5432
#
# Epoch 00006: val_loss did not improve from 0.67797
# Epoch 7/100
# 110/110 [==============================] - 10s 82ms/step - loss: 0.6138 - accuracy: 0.6603 - val_loss: 0.7382 - val_accuracy: 0.5469
#
# Epoch 00007: val_loss did not improve from 0.67797
# Epoch 8/100
# 110/110 [==============================] - 10s 79ms/step - loss: 0.5817 - accuracy: 0.6887 - val_loss: 0.7558 - val_accuracy: 0.5527
#
# Epoch 00008: val_loss did not improve from 0.67797
# Epoch 9/100
# 110/110 [==============================] - 10s 83ms/step - loss: 0.5344 - accuracy: 0.7270 - val_loss: 0.8116 - val_accuracy: 0.5378
#
# Epoch 00009: val_loss did not improve from 0.67797
# Epoch 10/100
# 110/110 [==============================] - 11s 90ms/step - loss: 0.4751 - accuracy: 0.7680 - val_loss: 0.9027 - val_accuracy: 0.5462
#
# Epoch 00010: val_loss did not improve from 0.67797
# Epoch 11/100
# 110/110 [==============================] - 10s 84ms/step - loss: 0.4078 - accuracy: 0.8125 - val_loss: 0.9744 - val_accuracy: 0.5473
#
# Epoch 00011: val_loss did not improve from 0.67797
# Epoch 12/100
# 110/110 [==============================] - 10s 80ms/step - loss: 0.3284 - accuracy: 0.8572 - val_loss: 1.0921 - val_accuracy: 0.5525
#
# Epoch 00012: val_loss did not improve from 0.67797
# Epoch 13/100
# 110/110 [==============================] - 9s 78ms/step - loss: 0.2625 - accuracy: 0.8912 - val_loss: 1.2434 - val_accuracy: 0.5383
#
# Epoch 00013: val_loss did not improve from 0.67797
# Epoch 14/100
# 110/110 [==============================] - 9s 77ms/step - loss: 0.2110 - accuracy: 0.9183 - val_loss: 1.3777 - val_accuracy: 0.5451
#
# Epoch 00014: val_loss did not improve from 0.67797
# Epoch 15/100
# 110/110 [==============================] - 10s 85ms/step - loss: 0.1571 - accuracy: 0.9438 - val_loss: 1.5149 - val_accuracy: 0.5415
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.67797
# Epoch 00015: early stopping
# 37/37 [==============================] - 2s 40ms/step - loss: 1.2518 - accuracy: 0.6019
# Validation acc: 0.6019
# Validation AUC: 0.6026
# Validation Balanced_ACC: 0.1724
# Validation MI: 0.0186
# Validation Normalized MI: 0.0270
# Validation Adjusted MI: 0.0270

# %%
ACC
# Out:
# array([0.57760102, 0.58447981, 0.58211523, 0.59350818, 0.58383489,
#        0.57953566, 0.56706792, 0.59909719, 0.59135854, 0.60189164])

# %%
print('Average Accuracy: ', np.round( ACC.mean(),4)*100) 
print('Average std: ',np.round(np.std( ACC),4)*100)
print('==============================================')
print('Average AUC: ', np.round( AUC.mean(),4)*100) 
print('Average AUC std: ',np.round(np.std( AUC),4)*100)
print('==============================================')
print('Average Balanced Accuracy: ', np.round( BACC.mean(),4)*100) 
print('Average std: ',np.round(np.std( BACC),4)*100)
print('==============================================')
print('Average MI: ', np.round( MI.mean(),4)*100) 
print('Average std: ',np.round(np.std(MI),4)*100)
print('==============================================')
print('Average Normalized MI: ', np.round( NMI.mean(),4)*100) 
print('Average std: ',np.round(np.std(NMI),4)*100)
print('==============================================')
print('Average Ajdusted MI: ', np.round( AMI.mean(),4)*100) 
print('Average std: ',np.round(np.std(AMI),4)*100)
# Out:
# Average Accuracy:  58.599999999999994
# Average std:  1.0
# ==============================================
# Average AUC:  58.63
# Average AUC std:  0.98
# ==============================================
# Average Balanced Accuracy:  16.5
# Average std:  0.51
# ==============================================
# Average MI:  1.72
# Average std:  0.09
# ==============================================
# Average Normalized MI:  2.5
# Average std:  0.12
# ==============================================
# Average Ajdusted MI:  2.5
# Average std:  0.12

# %%
print('Average Accuracy: ', np.round(val_acc_goldst.mean(),4)*100) 
print('STD Accuracy: ', np.round(np.std(val_acc_goldst),4)*100)
# Out:
# Average Accuracy:  0.0
# STD Accuracy:  0.0

# %%
AUC
# Out:
# array([0.5763768 , 0.58470422, 0.58190072, 0.59388918, 0.58451414,
#        0.58119142, 0.56806386, 0.59766865, 0.59202796, 0.6026035 ])

# %%
print('Average AUC: ', np.round(AUC.mean(),4)*100) 
print('STD AUC: ', np.round(np.std(AUC),4)*100)
# Out:
# Average AUC:  58.63
# STD AUC:  0.98

# %%
np.round(np.mean(AUC),4)*100
# Out:
# 58.63

# %%
    # Create the history figure
    plt.figure(figsize=(16,9))
    for i in trainHistory.history:
        plt.plot(trainHistory.history[i],label=i)
    plt.title('Model history')
    plt.legend()
    plt.grid()

# %%
val_acc_goldst.mean()
# Out:
# 0.0

# %%
AUC
# Out:
# array([0.5763768 , 0.58470422, 0.58190072, 0.59388918, 0.58451414,
#        0.58119142, 0.56806386, 0.59766865, 0.59202796, 0.6026035 ])

# %%
print('Average Accuracy: ', np.round( val_acc_goldst.mean(),4)*100) 
print('Average std: ',np.round(np.std( val_acc_goldst),4)*100)
# Out:
# Average Accuracy:  0.0
# Average std:  0.0

# %%
print('Average Accuracy: ', np.round( AUC.mean(),4)*100) 
print('Average std: ',np.round(np.std( AUC),4)*100)
# Out:
# Average Accuracy:  58.63
# Average std:  0.98
